# %% [markdown]
# <a href="https://colab.research.google.com/github/pankajroy97/Skill-Academy-Data-Science-Internship-Project-/blob/main/Amazing_Mart_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('/content/Order (2).xlsx')

# %%
df1= pd.read_json('/content/Order_breakdown.json')

# %%
df.head()
# Out:
#           Order ID Order Date     Customer Name        City         Country  \
# 0  BN-2011-7407039 2013-01-01        Ruby Patel   Stockholm          Sweden
# 1  AZ-2011-9050313 2013-01-03    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300 2013-01-04  Devin Huddleston     Valence          France
# 3  BN-2011-2819714 2013-01-04       Mary Parker  Birmingham  United Kingdom
# 4   AZ-2011-617423 2013-01-05      Daniel Burke  Echirolles          France
#
#     Region      Segment  Ship Date     Ship Mode                 State  \
# 0    North  Home Office 2013-01-05  Economy Plus             Stockholm
# 1    North     Consumer 2013-01-07       Economy               England
# 2  Central     Consumer 2013-01-08       Economy  Auvergne-Rhône-Alpes
# 3    North    Corporate 2013-01-09       Economy               England
# 4  Central  Home Office 2013-01-07      Priority  Auvergne-Rhône-Alpes
#
#    Days to Ship
# 0             4
# 1             4
# 2             4
# 3             5
# 4             2

# %%
df1.head()
# Out:
#           Order ID                           Product Name  Discount  \
# 0  BN-2011-7407039            Enermax Note Cards, Premium       0.5
# 1  AZ-2011-9050313     Dania Corner Shelving, Traditional       0.0
# 2  AZ-2011-6674300  Binney & Smith Sketch Pad, Easy-Erase       0.0
# 3  BN-2011-2819714             Boston Markers, Easy-Erase       0.5
# 4  BN-2011-2819714            Eldon Folders, Single Width       0.5
#
#    Actual Discount  Sales  Profit  Quantity         Category Sub-Category
# 0             22.5     45     -26         3  Office Supplies        Paper
# 1              0.0    854     290         7        Furniture    Bookcases
# 2              0.0    140      21         3  Office Supplies          Art
# 3             13.5     27     -22         2  Office Supplies          Art
# 4              8.5     17      -1         2  Office Supplies      Storage

# %%
df1[df1['Order ID']=='AZ-2011-6674300']
# Out:
#           Order ID                           Product Name  Discount  \
# 2  AZ-2011-6674300  Binney & Smith Sketch Pad, Easy-Erase       0.0
#
#    Actual Discount  Sales  Profit  Quantity         Category Sub-Category
# 2              0.0    140      21         3  Office Supplies          Art

# %% [markdown]
# Data Pre-Processing

# %%
df.shape
# Out:
# (4117, 11)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4117 entries, 0 to 4116
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       4117 non-null   object
#  1   Order Date     4117 non-null   datetime64[ns]
#  2   Customer Name  4117 non-null   object
#  3   City           4117 non-null   object
#  4   Country        4117 non-null   object
#  5   Region         4117 non-null   object
#  6   Segment        4117 non-null   object
#  7   Ship Date      4117 non-null   datetime64[ns]
#  8   Ship Mode      4117 non-null   object
#  9   State          4117 non-null   object
#  10  Days to Ship   4117 non-null   int64
# dtypes: datetime64[ns](2), int64(1), object(8)
# memory usage: 353.9+ KB

# %%
df.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Customer Name    0
# City             0
# Country          0
# Region           0
# Segment          0
# Ship Date        0
# Ship Mode        0
# State            0
# Days to Ship     0
# dtype: int64

# %%
df.describe()
# Out:
#        Days to Ship
# count   4117.000000
# mean       3.968181
# std        1.735192
# min        0.000000
# 25%        3.000000
# 50%        4.000000
# 75%        5.000000
# max        7.000000

# %%
df[df1['Order ID']=='AZ-2011-6674300']
# Out:
#           Order ID Order Date     Customer Name     City Country   Region  \
# 2  AZ-2011-6674300 2013-01-04  Devin Huddleston  Valence  France  Central
#
#     Segment  Ship Date Ship Mode                 State  Days to Ship
# 2  Consumer 2013-01-08   Economy  Auvergne-Rhône-Alpes             4

# %%
data=pd.merge(df,df1,on='Order ID')

# %%
data.head()
# Out:
#           Order ID Order Date     Customer Name        City         Country  \
# 0  BN-2011-7407039 2013-01-01        Ruby Patel   Stockholm          Sweden
# 1  AZ-2011-9050313 2013-01-03    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300 2013-01-04  Devin Huddleston     Valence          France
# 3  BN-2011-2819714 2013-01-04       Mary Parker  Birmingham  United Kingdom
# 4  BN-2011-2819714 2013-01-04       Mary Parker  Birmingham  United Kingdom
#
#     Region      Segment  Ship Date     Ship Mode                 State  \
# 0    North  Home Office 2013-01-05  Economy Plus             Stockholm
# 1    North     Consumer 2013-01-07       Economy               England
# 2  Central     Consumer 2013-01-08       Economy  Auvergne-Rhône-Alpes
# 3    North    Corporate 2013-01-09       Economy               England
# 4    North    Corporate 2013-01-09       Economy               England
#
#    Days to Ship                           Product Name  Discount  \
# 0             4            Enermax Note Cards, Premium       0.5
# 1             4     Dania Corner Shelving, Traditional       0.0
# 2             4  Binney & Smith Sketch Pad, Easy-Erase       0.0
# 3             5             Boston Markers, Easy-Erase       0.5
# 4             5            Eldon Folders, Single Width       0.5
#
#    Actual Discount  Sales  Profit  Quantity         Category Sub-Category
# 0             22.5     45     -26         3  Office Supplies        Paper
# 1              0.0    854     290         7        Furniture    Bookcases
# 2              0.0    140      21         3  Office Supplies          Art
# 3             13.5     27     -22         2  Office Supplies          Art
# 4              8.5     17      -1         2  Office Supplies      Storage

# %%
data.shape
# Out:
# (8047, 19)

# %%
data.isnull().sum()
# Out:
# Order ID           0
# Order Date         0
# Customer Name      0
# City               0
# Country            0
# Region             0
# Segment            0
# Ship Date          0
# Ship Mode          0
# State              0
# Days to Ship       0
# Product Name       0
# Discount           0
# Actual Discount    0
# Sales              0
# Profit             0
# Quantity           0
# Category           0
# Sub-Category       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8047 entries, 0 to 8046
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order ID         8047 non-null   object
#  1   Order Date       8047 non-null   datetime64[ns]
#  2   Customer Name    8047 non-null   object
#  3   City             8047 non-null   object
#  4   Country          8047 non-null   object
#  5   Region           8047 non-null   object
#  6   Segment          8047 non-null   object
#  7   Ship Date        8047 non-null   datetime64[ns]
#  8   Ship Mode        8047 non-null   object
#  9   State            8047 non-null   object
#  10  Days to Ship     8047 non-null   int64
#  11  Product Name     8047 non-null   object
#  12  Discount         8047 non-null   float64
#  13  Actual Discount  8047 non-null   float64
#  14  Sales            8047 non-null   int64
#  15  Profit           8047 non-null   int64
#  16  Quantity         8047 non-null   int64
#  17  Category         8047 non-null   object
#  18  Sub-Category     8047 non-null   object
# dtypes: datetime64[ns](2), float64(2), int64(4), object(11)
# memory usage: 1.2+ MB

# %%
data.columns
# Out:
# Index(['Order ID', 'Order Date', 'Customer Name', 'City', 'Country', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State', 'Days to Ship',
#        'Product Name', 'Discount', 'Actual Discount', 'Sales', 'Profit',
#        'Quantity', 'Category', 'Sub-Category'],
#       dtype='object')

# %%
data['Order ID'].nunique()
# Out:
# 4117

# %%
data['Customer Name'].nunique()
# Out:
# 792

# %%
data['City'].nunique()
# Out:
# 999

# %%
print(data['Country'].nunique())
data['Country'].unique()
# Out:
# 15
# array(['Sweden', 'United Kingdom', 'France', 'Italy', 'Austria', 'Spain',
#        'Germany', 'Netherlands', 'Denmark', 'Belgium', 'Norway',
#        'Portugal', 'Switzerland', 'Ireland', 'Finland'], dtype=object)

# %%
print(data['Region'].nunique())
data['Region'].unique()
# Out:
# 3
# array(['North', 'Central', 'South'], dtype=object)

# %%
print(data['Segment'].nunique())
data['Segment'].unique()
# Out:
# 3
# array(['Home Office', 'Consumer', 'Corporate'], dtype=object)

# %%
print(data['State'].nunique())
# Out:
# 127

# %%
print(data['State'].nunique())
# Out:
# 127

# %%
print(data['Days to Ship'].nunique())
data['Days to Ship'].unique()
# Out:
# 8
# array([4, 5, 2, 1, 6, 0, 7, 3])

# %% [markdown]
# #Plot of Monthly sales

# %%
# convert the datetime object to the desired date format
data['Order Date']=pd.to_datetime(data['Order Date'])

# %%
data['Order_month']=data['Order Date'].dt.month

# %%
data.describe()
# Out:
#        Days to Ship     Discount  Actual Discount        Sales       Profit  \
# count   8047.000000  8047.000000      8047.000000  8047.000000  8047.000000
# mean       4.007332     0.110047        29.793078   291.845657    35.198211
# std        1.741232     0.181773        88.817656   485.212156   178.125844
# min        0.000000     0.000000         0.000000     3.000000 -3060.000000
# 25%        3.000000     0.000000         0.000000    48.000000     1.000000
# 50%        4.000000     0.000000         0.000000   117.000000    14.000000
# 75%        5.000000     0.100000        22.000000   313.000000    47.000000
# max        7.000000     0.850000      1700.000000  6517.000000  2476.000000
#
#           Quantity  Order_month
# count  8047.000000  8047.000000
# mean      3.772089     7.352802
# std       2.203369     3.326043
# min       1.000000     1.000000
# 25%       2.000000     5.000000
# 50%       3.000000     8.000000
# 75%       5.000000    10.000000
# max      14.000000    12.000000

# %% [markdown]
# ###Exploratory Data Analysis

# %% [markdown]
# ###Plot country wise sales

# %%
CWS=data.groupby('Country')['Sales'].sum().reset_index().sort_values(by='Sales',ascending=False)[0:10]
CWS
# Out:
#            Country   Sales
# 4           France  609683
# 5          Germany  488681
# 14  United Kingdom  420497
# 7            Italy  252742
# 11           Spain  249402
# 0          Austria   79382
# 8      Netherlands   70313
# 1          Belgium   42320
# 12          Sweden   30490
# 13     Switzerland   24874

# %%
ax=sns.barplot(data=CWS,x='Country',y='Sales')
plt.title('Country wise sales',fontsize=30)

ax.set_xticklabels(ax.get_xticklabels(),rotation=70)
plt.show()

# %% [markdown]
# ###How sales vary across different product categories

# %%
CatWS=data.groupby(['Category','Sub-Category'])['Sales'].sum().reset_index().sort_values(by='Sales',ascending=False)
CatWS
# Out:
#            Category Sub-Category   Sales
# 0         Furniture    Bookcases  294396
# 14       Technology      Copiers  290081
# 16       Technology       Phones  282559
# 11  Office Supplies      Storage  272489
# 4   Office Supplies   Appliances  209900
# 1         Furniture       Chairs  186698
# 15       Technology     Machines  182066
# 13       Technology  Accessories  131309
# 5   Office Supplies          Art  127184
# 3         Furniture       Tables   89478
# 6   Office Supplies      Binders   78934
# 2         Furniture  Furnishings   68237
# 12  Office Supplies     Supplies   38824
# 10  Office Supplies        Paper   36057
# 7   Office Supplies    Envelopes   31210
# 8   Office Supplies    Fasteners   16238
# 9   Office Supplies       Labels   12822

# %%
sales_by_category = CatWS.groupby('Category')['Sales'].sum().reset_index().sort_values(by='Sales',ascending=False)

plt.pie(sales_by_category['Sales'], labels=sales_by_category['Category'], autopct='%1.1f%%')
plt.title('Total Sales by Category', fontsize=30)
plt.show()

# %%
plt.style.use('seaborn')

ax=sns.boxplot(y="Category",x="Sales",data =CatWS)
ax.set_title(label = " Total sales of product", fontsize = 25)
ax.set_xlabel(xlabel = "Total sales", fontsize = 16)
ax.set_ylabel(ylabel = "Category", fontsize = 16)
# Out:
# Text(0, 0.5, 'Category')

# %% [markdown]
# ###Plot Sub-Category wise sales

# %%
furniture_df = CatWS[CatWS['Category'] == 'Furniture']

sns.barplot(x='Sub-Category', y='Sales', data=furniture_df)
plt.xlabel('Furniture')
plt.ylabel('Sales')
plt.title('Sales for Furniture Category', fontsize=30)
plt.show()

# %%
Office_supplies_df = CatWS[CatWS['Category'] == 'Office Supplies']

ax=sns.barplot(x='Sub-Category', y='Sales', data=Office_supplies_df)

for bars in ax.containers:
    ax.bar_label(bars)
plt.xticks(rotation=70)
plt.xlabel('Office Supplies')
plt.ylabel('Sales')
plt.title('Sales for Office Supplies Category', fontsize=30)
plt.show()

# %%
import seaborn as sns

Technology_df = CatWS[CatWS['Category'] == 'Technology']

ax=sns.barplot(x='Sub-Category', y='Sales', data=Technology_df)

for bars in ax.containers:
    ax.bar_label(bars)
plt.xlabel('Technology')
plt.ylabel('Sales')
plt.title('Sales for Technology Category', fontsize=30)
plt.show()

# %% [markdown]
# ###Plot sub catogory wise profits

# %%
Cat_Wise_Profit=data.groupby(['Category','Sub-Category'])['Profit'].sum().reset_index().sort_values(by='Profit',ascending=False)

# %%
Cat_Wise_Profit.iloc[:10, 1:3]
# Out:
#    Sub-Category  Profit
# 0     Bookcases   43655
# 14      Copiers   42775
# 4    Appliances   37906
# 16       Phones   27631
# 13  Accessories   26830
# 5           Art   23491
# 11      Storage   21995
# 1        Chairs   15489
# 6       Binders   14703
# 2   Furnishings   11321

# %%
ax=sns.barplot(data=Cat_Wise_Profit,x='Profit',y='Sub-Category')

for bars in ax.containers:
    ax.bar_label(bars)

plt.title('Sub catogory wise profits ', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Sub catogory wise profits ')

# %% [markdown]
# ###Plot of Monthly sales

# %%
# convert the datetime object to the desired date format
data['Order Date']=pd.to_datetime(data['Order Date'])

# %%
data['Order_month']=data['Order Date'].dt.month

# %%
data.head()
# Out:
#           Order ID Order Date     Customer Name        City         Country  \
# 0  BN-2011-7407039 2013-01-01        Ruby Patel   Stockholm          Sweden
# 1  AZ-2011-9050313 2013-01-03    Summer Hayward   Southport  United Kingdom
# 2  AZ-2011-6674300 2013-01-04  Devin Huddleston     Valence          France
# 3  BN-2011-2819714 2013-01-04       Mary Parker  Birmingham  United Kingdom
# 4  BN-2011-2819714 2013-01-04       Mary Parker  Birmingham  United Kingdom
#
#     Region      Segment  Ship Date     Ship Mode                 State  \
# 0    North  Home Office 2013-01-05  Economy Plus             Stockholm
# 1    North     Consumer 2013-01-07       Economy               England
# 2  Central     Consumer 2013-01-08       Economy  Auvergne-Rhône-Alpes
# 3    North    Corporate 2013-01-09       Economy               England
# 4    North    Corporate 2013-01-09       Economy               England
#
#    Days to Ship                           Product Name  Discount  \
# 0             4            Enermax Note Cards, Premium       0.5
# 1             4     Dania Corner Shelving, Traditional       0.0
# 2             4  Binney & Smith Sketch Pad, Easy-Erase       0.0
# 3             5             Boston Markers, Easy-Erase       0.5
# 4             5            Eldon Folders, Single Width       0.5
#
#    Actual Discount  Sales  Profit  Quantity         Category Sub-Category  \
# 0             22.5     45     -26         3  Office Supplies        Paper
# 1              0.0    854     290         7        Furniture    Bookcases
# 2              0.0    140      21         3  Office Supplies          Art
# 3             13.5     27     -22         2  Office Supplies          Art
# 4              8.5     17      -1         2  Office Supplies      Storage
#
#    Order_month
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
monthlysales = data.groupby('Order_month')['Sales'].sum().reset_index().sort_values(by='Order_month', ascending=True)
month=range(1,13)
sns.lineplot(data=monthlysales,x=month,y='Sales')
plt.title('Month wise sales  ', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Month wise sales  ')

# %% [markdown]
# ###Top 10 Highest selling products

# %%
highestselling=data.groupby('Product Name')['Sales'].sum().reset_index().sort_values(by='Sales',ascending=False)[0:10]
highestselling
# Out:
#                                            Product Name  Sales
# 1223                       Nokia Smart Phone, Full Size  30645
# 832                        Hamilton Beach Stove, Silver  16890
# 475                         Cisco Smart Phone, Cordless  14723
# 1243            Novimex Executive Leather Armchair, Red  13898
# 477                   Cisco Smart Phone, with Caller ID  13215
# 1367                     Rogers File Cart, Single Width  12967
# 966                                   Hoover Stove, Red  12677
# 149                        Apple Smart Phone, Full Size  12555
# 1303  Office Star Executive Leather Armchair, Adjust...  11687
# 582                       Eldon File Cart, Single Width  11233

# %%
ax=sns.barplot(data=highestselling, x='Sales',y='Product Name')

for bars in ax.containers:
    ax.bar_label(bars)

plt.title('Top 10 Highest selling products ', fontsize=30)

plt.show()

# %% [markdown]
# ###How sales vary across different shipping modes.

# %%
Shipmode_w_sales=data.groupby('Ship Mode')['Sales'].sum().reset_index()
Shipmode_w_sales
# Out:
#       Ship Mode    Sales
# 0       Economy  1412777
# 1  Economy Plus   483965
# 2     Immediate   131314
# 3      Priority   320426

# %%
sns.barplot(data=Shipmode_w_sales,x='Ship Mode',y='Sales')
plt.title('how sales vary across different shipping modes. ', fontsize=30)

plt.show()

# %% [markdown]
# ###Bar plot of sales against segmentation

# %%
Segment_w_sales=data.groupby(['Segment','Order_month'])['Sales'].sum().reset_index()
# create a bar plot of the sales by segment and month
ax = sns.barplot(data=Segment_w_sales,x='Order_month',y='Sales',hue='Segment')
# set the plot title and axis labels
ax.set_title('Monthly Sales by Segment')
ax.set_xlabel('Month')
ax.set_ylabel('Sales')
# show the plot
plt.show()

# %% [markdown]
# ###Relationship between profit and actual discount for each data point

# %%
sns.scatterplot(data=data,x='Profit',y='Actual Discount')
# Out:
# <Axes: xlabel='Profit', ylabel='Actual Discount'>

# %% [markdown]
# ###Correlation between numerical data

# %%
corr_matrix=data.corr()
corr_matrix
# Out:
#                  Days to Ship  Discount  Actual Discount     Sales    Profit  \
# Days to Ship         1.000000  0.017281        -0.019068 -0.004595  0.014128
# Discount             0.017281  1.000000         0.426115 -0.026350 -0.351328
# Actual Discount     -0.019068  0.426115         1.000000  0.478904 -0.395875
# Sales               -0.004595 -0.026350         0.478904  1.000000  0.441217
# Profit               0.014128 -0.351328        -0.395875  0.441217  1.000000
# Quantity             0.001472  0.003686         0.207153  0.353441  0.098670
# Order_month          0.008223  0.007899         0.003791 -0.001520  0.002309
#
#                  Quantity  Order_month
# Days to Ship     0.001472     0.008223
# Discount         0.003686     0.007899
# Actual Discount  0.207153     0.003791
# Sales            0.353441    -0.001520
# Profit           0.098670     0.002309
# Quantity         1.000000     0.006564
# Order_month      0.006564     1.000000

# %%
sns.heatmap(corr_matrix,cmap="coolwarm", annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ###Box plot for numerical columns

# %%
cat_cols=data.dtypes[data.dtypes=='object'].index
num_cols=data.dtypes[data.dtypes!='object'].index
print(len(cat_cols)," ",cat_cols)
print(len(num_cols)," ",num_cols)
# Out:
# 11   Index(['Order ID', 'Customer Name', 'City', 'Country', 'Region', 'Segment',
#        'Ship Mode', 'State', 'Product Name', 'Category', 'Sub-Category'],
#       dtype='object')
# 9   Index(['Order Date', 'Ship Date', 'Days to Ship', 'Discount',
#        'Actual Discount', 'Sales', 'Profit', 'Quantity', 'Order_month'],
#       dtype='object')

# %%
numcols2=data[['Discount','Actual Discount','Sales','Profit','Quantity']]

# %%
for i in numcols2:
    sns.boxplot(x=data[i])
    plt.title(f'Boxplot for {i}')
    plt.show()

# %%
#Treating the outliers in Discount columns
import numpy as np
median=data[data['Discount']>=0.10]['Discount'].median()
data['Discount']=np.where(data['Discount']>=0.60,median,data['Discount'])
median
# Out:
# 0.15

# %%
sns.boxplot(x=data['Discount'])
plt.title('Boxplot for Discount ')
plt.show()

# %% [markdown]
# ###Selecting Dependent and Independent Features

# %%
data.rename(columns={'Actual Discount':'Actual_Discount'},inplace=True)

data['Discount_Percentage']=data['Discount']*100
print(data.columns)
data['Discount_Percentage'] = data['Discount_Percentage'].astype(int)
# Out:
# Index(['Order ID', 'Order Date', 'Customer Name', 'City', 'Country', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State', 'Days to Ship',
#        'Product Name', 'Discount', 'Actual_Discount', 'Sales', 'Profit',
#        'Quantity', 'Category', 'Sub-Category', 'Order_month',
#        'Discount_Percentage'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Order ID', 'Order Date', 'Customer Name', 'City', 'Country', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State', 'Days to Ship',
#        'Product Name', 'Discount', 'Actual_Discount', 'Sales', 'Profit',
#        'Quantity', 'Category', 'Sub-Category', 'Order_month',
#        'Discount_Percentage'],
#       dtype='object')

# %%
x = data[['Country', 'Region', 'Segment', 'Category', 'Sub-Category','Discount_Percentage', 'Actual_Discount', 'Quantity', 'Order_month']]
y=data['Sales']

# %%
x.head()
# Out:
#           Country   Region      Segment         Category Sub-Category  \
# 0          Sweden    North  Home Office  Office Supplies        Paper
# 1  United Kingdom    North     Consumer        Furniture    Bookcases
# 2          France  Central     Consumer  Office Supplies          Art
# 3  United Kingdom    North    Corporate  Office Supplies          Art
# 4  United Kingdom    North    Corporate  Office Supplies      Storage
#
#    Discount_Percentage  Actual_Discount  Quantity  Order_month
# 0                   50             22.5         3            1
# 1                    0              0.0         7            1
# 2                    0              0.0         3            1
# 3                   50             13.5         2            1
# 4                   50              8.5         2            1

# %%
print(type(x))
print(type(y))
print(x.shape)
print(y.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# (8047, 9)
# (8047,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=20)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (5632, 9)
# (2415, 9)
# (5632,)
# (2415,)

# %% [markdown]
# ###Evaluate problem of regression model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
def eval_model(ytest,ypred):
    mae=mean_absolute_error(ytest,ypred)
    mse=mean_squared_error(ytest,ypred)
    rmse=np.sqrt(mse)
    r2score=r2_score(ytest,ypred)
    print('MAE',mae)
    print('MSE',mse)
    print('RMSE',rmse)
    print('R2_SCORE',r2score)

def mscore(model):
    print('Training Score',model.score(x_train,y_train))
    print('Testing score',model.score(x_test,y_test))

# %%
print(data.columns)
print(cat_cols)
print('X train columns',x_train.columns)
# Out:
# Index(['Order ID', 'Order Date', 'Customer Name', 'City', 'Country', 'Region',
#        'Segment', 'Ship Date', 'Ship Mode', 'State', 'Days to Ship',
#        'Product Name', 'Discount', 'Actual_Discount', 'Sales', 'Profit',
#        'Quantity', 'Category', 'Sub-Category', 'Order_month',
#        'Discount_Percentage'],
#       dtype='object')
# Index(['Order ID', 'Customer Name', 'City', 'Country', 'Region', 'Segment',
#        'Ship Mode', 'State', 'Product Name', 'Category', 'Sub-Category'],
#       dtype='object')
# X train columns Index(['Country', 'Region', 'Segment', 'Category', 'Sub-Category',
#        'Discount_Percentage', 'Actual_Discount', 'Quantity', 'Order_month'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %% [markdown]
# ###1) Linear Regression

# %%
import warnings
warnings.filterwarnings('ignore')

s1=ColumnTransformer(transformers=[('encoder',OneHotEncoder(drop='first',sparse=False,handle_unknown='ignore'),[0,1,2,3,4])],
                     remainder='passthrough')

s2=LinearRegression()

pipe_lr=Pipeline([('s1',s1),('s2',s2)])

pipe_lr.fit(x_train,y_train)
ypred_lr=pipe_lr.predict(x_test)
eval_model(y_test,ypred_lr)
# Out:
# MAE 187.37597920011376
# MSE 119728.58673166715
# RMSE 346.0181884405315
# R2_SCORE 0.5143725960770109

# %%
mscore(pipe_lr)
# Out:
# Training Score 0.5309777795413033
# Testing score 0.5143725960770109

# %% [markdown]
# 2. DecisionTree Regression Model

# %%
s1=ColumnTransformer(transformers=[('encoder',OneHotEncoder(drop='first',sparse=False,handle_unknown='ignore'),[0,1,2,3,4])],
                     remainder='passthrough')

s2=DecisionTreeRegressor(criterion='squared_error',max_depth=10,min_samples_split=15)

pipe_dt=Pipeline([('s1',s1),('s2',s2)])

pipe_dt.fit(x_train,y_train)
ypred_dt=pipe_dt.predict(x_test)
print(eval_model(y_test,ypred_dt))
print(mscore(pipe_dt))
# Out:
# MAE 118.16758803641727
# MSE 84663.20534814113
# RMSE 290.96942339039873
# R2_SCORE 0.6566002009765458
# None
# Training Score 0.781824192000824
# Testing score 0.6566002009765458
# None

# %% [markdown]
# 3) RF Regression

# %%
s1=ColumnTransformer(transformers=[('encoder',OneHotEncoder(drop='first',sparse=False,handle_unknown='ignore'),[0,1,2,3,4])],
                     remainder='passthrough')

s2=RandomForestRegressor(n_estimators=100,criterion='squared_error',max_depth=10,min_samples_split=15)

pipe_rfr=Pipeline([('s1',s1),('s2',s2)])

pipe_rfr.fit(x_train,y_train)
ypred_rfr=pipe_rfr.predict(x_test)
print(eval_model(y_test,ypred_rfr))
mscore(pipe_rfr)
# Out:
# MAE 110.72683603360412
# MSE 71166.08145294254
# RMSE 266.76971614660937
# R2_SCORE 0.7113454662183563
# None
# Training Score 0.7942068791798481
# Testing score 0.7113454662183563

# %% [markdown]
# 4) KNN Regression

# %%
s1=ColumnTransformer(transformers=[('encoder',OneHotEncoder(drop='first',sparse=False,handle_unknown='ignore'),[0,1,2,3,4])],
                     remainder='passthrough')

s2=KNeighborsRegressor(n_neighbors=7)

pipe_knn=Pipeline([('s1',s1),('s2',s2)])

pipe_knn.fit(x_train,y_train)
ypred_knn=pipe_knn.predict(x_test)
print(eval_model(y_test,ypred_knn))
mscore(pipe_knn)
# Out:
# MAE 120.82265601892932
# MSE 113785.4501457726
# RMSE 337.32098977942746
# R2_SCORE 0.5384783678910228
# None
# Training Score 0.6584160285600276
# Testing score 0.5384783678910228

# %% [markdown]
# 5) Ridge Regression

# %%
s1=ColumnTransformer(transformers=[('encoder',OneHotEncoder(drop='first',sparse=False,handle_unknown='ignore'),[0,1,2,3,4])],
                     remainder='passthrough')

s2=Ridge(alpha=4)

pipe_ridge=Pipeline([('s1',s1),('s2',s2)])

pipe_ridge.fit(x_train,y_train)
ypred_ridge=pipe_ridge.predict(x_test)
eval_model(y_test,ypred_ridge)
mscore(pipe_ridge)
# Out:
# MAE 187.08558083101298
# MSE 119701.94818330993
# RMSE 345.9796933106189
# R2_SCORE 0.5144806438660655
# Training Score 0.5308878933978619
# Testing score 0.5144806438660655

# %% [markdown]
# 3)Lasso Regression

# %%
s1=ColumnTransformer(transformers=[('encoder',OneHotEncoder(drop='first',sparse=False,handle_unknown='ignore'),[0,1,2,3,4])],
                     remainder='passthrough')

s2=Lasso(alpha=7)

pipe_lasso=Pipeline([('s1',s1),('s2',s2)])

pipe_lasso.fit(x_train,y_train)
ypred_lasso=pipe_lasso.predict(x_test)
print(eval_model(y_test,ypred_lasso))
mscore(pipe_lasso)
# Out:
# MAE 186.6331285165941
# MSE 128023.26569217962
# RMSE 357.803389715888
# R2_SCORE 0.4807288062359427
# None
# Training Score 0.4938361799271239
# Testing score 0.4807288062359427

# %% [markdown]
# In conclusion, based on the evaluation metrics, the Random Forest Regression model is the best model for predicting "Sales" on the given dataset. However, it is important to note that the performance of each model may vary depending on the dataset and the problem at hand.The evaluation metrics of Random Forest Regression model are
#
# MAE 110.01431654127552
#
# MSE 70487.50412289612
#
# RMSE 265.494828806318
#
# R2_SCORE 0.7140978226617676
#
# Training Score 0.7953140174067538
#
# Testing score 0.7140978226617676

# %% [markdown]
# Save the best model and Load the model

# %%
# Save the best model
import pickle
pickle.dump(pipe_rfr,open('random_forest.pkl','wb'))

# %%
#load the model
loaded_model=pickle.load(open('random_forest.pkl','rb'))
result=loaded_model.score(x_test,y_test)
result
# Out:
# 0.7113454662183563

# %% [markdown]
# Take the original dataset and make another dataset by randomly picking 20 datapoints from the dataset and apply the saved model on the same

# %%
data_sample=data.sample(n=20)

# %%
data_sample.head()
# Out:
#              Order ID Order Date   Customer Name        City         Country  \
# 1372  AZ-2011-3096034 2013-12-19      Katie Thom       Mijas           Spain
# 1326  BN-2011-4097137 2013-12-13     Holly Noble     Amadora        Portugal
# 5061  AZ-2013-6132734 2015-11-12       Ewan Hyde  Strasbourg          France
# 6740  AZ-2014-7795641 2016-08-13    Lily Skurrie   Doncaster  United Kingdom
# 1651  AZ-2012-1128813 2014-03-06  Hayden Perkins      Vanves          France
#
#        Region    Segment  Ship Date     Ship Mode  \
# 1372    South  Corporate 2013-12-23       Economy
# 1326    South   Consumer 2013-12-18       Economy
# 5061  Central   Consumer 2015-11-16       Economy
# 6740    North  Corporate 2016-08-13     Immediate
# 1651  Central   Consumer 2014-03-10  Economy Plus
#
#                                   State  ...  \
# 1372                          Andalusía  ...
# 1326                             Lisboa  ...
# 5061  Alsace-Champagne-Ardenne-Lorraine  ...
# 6740                            England  ...
# 1651                      Ile-de-France  ...
#
#                               Product Name Discount  Actual_Discount  Sales  \
# 1372  Novimex Removable Labels, Adjustable      0.0              0.0     41
# 1326        Deflect-O Photo Frame, Durable      0.5             61.0    122
# 5061   Rubbermaid Stacking Tray, Erganomic      0.0              0.0     44
# 6740          Fellowes Folders, Wire Frame      0.0              0.0    229
# 1651             Xerox Note Cards, Premium      0.0              0.0    132
#
#       Profit  Quantity         Category Sub-Category Order_month  \
# 1372       4         4  Office Supplies       Labels          12
# 1326     -88         5        Furniture  Furnishings          12
# 5061       0         2        Furniture  Furnishings          11
# 6740      59         9  Office Supplies      Storage           8
# 1651      26         5  Office Supplies        Paper           3
#
#       Discount_Percentage
# 1372                    0
# 1326                   50
# 5061                    0
# 6740                    0
# 1651                    0
#
# [5 rows x 21 columns]

# %%
sample=data_sample.drop('Sales',axis=1)

# %%
sample.to_csv('sample_submission_capston_project.csv')

# %%
random_sample=pd.read_csv('/content/sample_submission_capston_project.csv')
random_sample.head()
# Out:
#    Unnamed: 0         Order ID  Order Date   Customer Name        City  \
# 0        1372  AZ-2011-3096034  2013-12-19      Katie Thom       Mijas
# 1        1326  BN-2011-4097137  2013-12-13     Holly Noble     Amadora
# 2        5061  AZ-2013-6132734  2015-11-12       Ewan Hyde  Strasbourg
# 3        6740  AZ-2014-7795641  2016-08-13    Lily Skurrie   Doncaster
# 4        1651  AZ-2012-1128813  2014-03-06  Hayden Perkins      Vanves
#
#           Country   Region    Segment   Ship Date     Ship Mode  ...  \
# 0           Spain    South  Corporate  2013-12-23       Economy  ...
# 1        Portugal    South   Consumer  2013-12-18       Economy  ...
# 2          France  Central   Consumer  2015-11-16       Economy  ...
# 3  United Kingdom    North  Corporate  2016-08-13     Immediate  ...
# 4          France  Central   Consumer  2014-03-10  Economy Plus  ...
#
#   Days to Ship                          Product Name Discount  \
# 0            4  Novimex Removable Labels, Adjustable      0.0
# 1            5        Deflect-O Photo Frame, Durable      0.5
# 2            4   Rubbermaid Stacking Tray, Erganomic      0.0
# 3            0          Fellowes Folders, Wire Frame      0.0
# 4            4             Xerox Note Cards, Premium      0.0
#
#    Actual_Discount  Profit  Quantity         Category Sub-Category  \
# 0              0.0       4         4  Office Supplies       Labels
# 1             61.0     -88         5        Furniture  Furnishings
# 2              0.0       0         2        Furniture  Furnishings
# 3              0.0      59         9  Office Supplies      Storage
# 4              0.0      26         5  Office Supplies        Paper
#
#   Order_month  Discount_Percentage
# 0          12                    0
# 1          12                   50
# 2          11                    0
# 3           8                    0
# 4           3                    0
#
# [5 rows x 21 columns]

# %%
random_sample.columns
# Out:
# Index(['Unnamed: 0', 'Order ID', 'Order Date', 'Customer Name', 'City',
#        'Country', 'Region', 'Segment', 'Ship Date', 'Ship Mode', 'State',
#        'Days to Ship', 'Product Name', 'Discount', 'Actual_Discount', 'Profit',
#        'Quantity', 'Category', 'Sub-Category', 'Order_month',
#        'Discount_Percentage'],
#       dtype='object')

# %%
random_sample=random_sample.drop(['Unnamed: 0','Order ID','Order Date','Customer Name','City','Ship Date','Ship Mode','State','Days to Ship','Product Name','Profit'],axis=1)
random_sample.head()
# Out:
#           Country   Region    Segment  Discount  Actual_Discount  Quantity  \
# 0           Spain    South  Corporate       0.0              0.0         4
# 1        Portugal    South   Consumer       0.5             61.0         5
# 2          France  Central   Consumer       0.0              0.0         2
# 3  United Kingdom    North  Corporate       0.0              0.0         9
# 4          France  Central   Consumer       0.0              0.0         5
#
#           Category Sub-Category  Order_month  Discount_Percentage
# 0  Office Supplies       Labels           12                    0
# 1        Furniture  Furnishings           12                   50
# 2        Furniture  Furnishings           11                    0
# 3  Office Supplies      Storage            8                    0
# 4  Office Supplies        Paper            3                    0

# %%
loaded_model=pickle.load(open('random_forest.pkl','rb'))
loaded_model_prediction=loaded_model.predict(random_sample)
loaded_model_prediction
# Out:
# array([  42.58837041,  144.31243968,   83.89536161,  424.12868196,
#         132.56857433,  217.13500896,  184.63880993,  838.14850738,
#        1652.4307088 ,   46.81003553,   68.55785377,   58.12666877,
#         126.78574162,   94.50875661, 1390.96210442,  495.2862949 ,
#          93.44478811,  646.98029881,   47.98488253,  141.50224506])

# %%
#  Compare the actual data and predicted data
data_sample["predicted_sales"] =np.round(loaded_model_prediction)
data_sample.head()
# Out:
#              Order ID Order Date   Customer Name        City         Country  \
# 1372  AZ-2011-3096034 2013-12-19      Katie Thom       Mijas           Spain
# 1326  BN-2011-4097137 2013-12-13     Holly Noble     Amadora        Portugal
# 5061  AZ-2013-6132734 2015-11-12       Ewan Hyde  Strasbourg          France
# 6740  AZ-2014-7795641 2016-08-13    Lily Skurrie   Doncaster  United Kingdom
# 1651  AZ-2012-1128813 2014-03-06  Hayden Perkins      Vanves          France
#
#        Region    Segment  Ship Date     Ship Mode  \
# 1372    South  Corporate 2013-12-23       Economy
# 1326    South   Consumer 2013-12-18       Economy
# 5061  Central   Consumer 2015-11-16       Economy
# 6740    North  Corporate 2016-08-13     Immediate
# 1651  Central   Consumer 2014-03-10  Economy Plus
#
#                                   State  ...  Discount Actual_Discount  Sales  \
# 1372                          Andalusía  ...       0.0             0.0     41
# 1326                             Lisboa  ...       0.5            61.0    122
# 5061  Alsace-Champagne-Ardenne-Lorraine  ...       0.0             0.0     44
# 6740                            England  ...       0.0             0.0    229
# 1651                      Ile-de-France  ...       0.0             0.0    132
#
#       Profit  Quantity         Category  Sub-Category Order_month  \
# 1372       4         4  Office Supplies        Labels          12
# 1326     -88         5        Furniture   Furnishings          12
# 5061       0         2        Furniture   Furnishings          11
# 6740      59         9  Office Supplies       Storage           8
# 1651      26         5  Office Supplies         Paper           3
#
#      Discount_Percentage  predicted_sales
# 1372                   0             43.0
# 1326                  50            144.0
# 5061                   0             84.0
# 6740                   0            424.0
# 1651                   0            133.0
#
# [5 rows x 22 columns]

# %%
data_sample.to_csv('Prediction_data_sample.csv')
